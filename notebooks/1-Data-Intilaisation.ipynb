# %%
from src.utils import unzip_directoy

# %%
unzip_directoy(
    zip_path="/mnt/c/Users/SZ388WX/OneDrive - EY/Documents/Personal/ieee_fraud_detection/data/raw/ieee-fraud-detection.zip",
    extract_dir="/mnt/c/Users/SZ388WX/OneDrive - EY/Documents/Personal/ieee_fraud_detection/data/raw/unzipped",
)
# Out:
# Extracting 5 files...
# Unzipping: 100%|██████████| 5/5 [00:16<00:00,  3.23s/file]
# Extraction completed at: /mnt/c/Users/SZ388WX/OneDrive - EY/Documents/Personal/ieee_fraud_detection/data/raw/unzipped
