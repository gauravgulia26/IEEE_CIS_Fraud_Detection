# %%
from src.entity.artifacts import DataIngestionArtifact
from src.utils import save_artifact_json, load_artifact_json
from src.configs.paths import PROJ_ROOT
from pathlib import Path

# %%
test_paths = Path("/a/b/c")

# %%
obj = DataIngestionArtifact(
    ident_test_data_path=test_paths,
    ident_train_data_path=test_paths,
    trns_test_data_path=test_paths,
    trns_train_data_path=test_paths,
    merged_file_path=test_paths,
)

# %%
file_save_path = PROJ_ROOT / "test.json"
save_artifact_json(obj, file_path=file_save_path)

# %%
artifact_json = load_artifact_json(file_path=file_save_path)
